# %% [markdown]
# # CAT Vehicle circular trajectory simulation

# %% [markdown]
# ## import required libraries

# %%
import sparkle
import os
from sparkle import lane
from sparkle import api
from sparkle import catvehicle
from sparkle import gzstats
homedir = os.path.expanduser("~")
import uuid
import glob
import bagpy
import pandas as pd
import signal
import  time
import seaborn as sea
from bagpy import bagreader

# %% [markdown]
# ## declare simulation parameters

# %%
datadir = homedir +"/CyverseData/ProjectSparkle/RTFvsNVehicles"
n_vehicles = 2
include_laser = False
circumference = 260
max_update_rate = 100.0 # for gazebo
time_step = 0.01 # for gazebo
leader_vel = 8.0
log_time = 60
unique_runid = str(uuid.uuid4())
description = "Circular Trajectory, Unique run ID = " + unique_runid


# 2.82321111
# wb = [2.82321111]

print("Wheelbase: {}".format(w))
sim_config = {"n_vehicles":  n_vehicles, 
              "include_laser": include_laser, 
              "circumference": circumference,
              "max_update_rate": max_update_rate, 
              "time_step": time_step, 
              "leader_vel": leader_vel,
              "log_time": log_time, 
              "description": description,
              "package_name": "catvehicle",
              "logdir": datadir}

C = catvehicle(**sim_config)
C.create()
C.spawn()
time.sleep(2)

C.control(leader_vel=leader_vel, logdir = datadir, )
C.rviz(C.package_path + "/config/magna_multi.rviz")
time.sleep(log_time)
C.destroy(signal.SIGINT)
# Out:
# Wheelbase: 2.82321111
# ************ Radius of the circle is 41.3802852039 ************
# Theta:3.14159265359 radian.
# Constant Steering Angle:=0.0681204300119
# Sparkle layout instance created.
# Number of CPU on this machine: 8
# PACKAGE NAME BEING EXECUTED IS catvehicle
# ... logging to /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/roslaunch-ivory-26424.log
# started roslaunch server http://ivory.local:41475/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /gazebo/enable_ros_network: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /
#     gazebo (gazebo_ros/gzserver)
#
# ROS_MASTER_URI=http://localhost:11311
# process[gazebo-1]: started with pid [26951]
# Empty world launched.
# Current  max_update_rate is 100.0
# 1e2a9482-15df-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/roslaunch-ivory-26424.log
# 1e2a9482-15df-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/roslaunch-ivory-26424.log
# started roslaunch server http://ivory.local:38527/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /magna/distanceEstimator/angle_max: 10.0
#  * /magna/distanceEstimator/angle_min: -10.0
#  * /magna/distanceEstimator/scan_topic: /magna/front_lase...
#  * /magna/front_left_steering_position_controller/joint: front_left_steeri...
#  * /magna/front_left_steering_position_controller/pid/d: 10.0
#  * /magna/front_left_steering_position_controller/pid/i: 0.01
#  * /magna/front_left_steering_position_controller/pid/p: 100.0
#  * /magna/front_left_steering_position_controller/type: position_controll...
#  * /magna/front_right_steering_position_controller/joint: front_right_steer...
#  * /magna/front_right_steering_position_controller/pid/d: 10.0
#  * /magna/front_right_steering_position_controller/pid/i: 0.01
#  * /magna/front_right_steering_position_controller/pid/p: 100.0
#  * /magna/front_right_steering_position_controller/type: position_controll...
#  * /magna/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /magna/joint1_velocity_controller/pid/d: 10.0
#  * /magna/joint1_velocity_controller/pid/i: 0.01
#  * /magna/joint1_velocity_controller/pid/p: 100.0
#  * /magna/joint1_velocity_controller/type: velocity_controll...
#  * /magna/joint2_velocity_controller/joint: back_right_wheel_...
#  * /magna/joint2_velocity_controller/pid/d: 10.0
#  * /magna/joint2_velocity_controller/pid/i: 0.01
#  * /magna/joint2_velocity_controller/pid/p: 100.0
#  * /magna/joint2_velocity_controller/type: velocity_controll...
#  * /magna/joint_state_controller/publish_rate: 50
#  * /magna/joint_state_controller/type: joint_state_contr...
#  * /magna/robot_description: <?xml version="1....
#  * /magna/tf_prefix: magna
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /magna/
#     base_link2slamodom_tf_magna (tf/static_transform_publisher)
#     cmdvel2gazebomagna (catvehicle/cmdvel2gazebo.py)
#     controller_spawnermagna (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_magna (tf/static_transform_publisher)
#     joint_state_publishermagna (joint_state_publisher/joint_state_publisher)
#     odom2pathmagna (catvehicle/odom2path.py)
#     robot_state_publishermagna (robot_state_publisher/robot_state_publisher)
#     urdf_spawnermagna (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[magna/urdf_spawnermagna-2]: started with pid [27219]
# process[magna/controller_spawnermagna-3]: started with pid [27220]
# process[magna/robot_state_publishermagna-4]: started with pid [27222]
# process[magna/joint_state_publishermagna-5]: started with pid [27223]
# process[magna/base_link2slamodom_tf_magna-6]: started with pid [27230]
# process[magna/cmdvel2gazebomagna-7]: started with pid [27232]
# process[magna/distanceEstimator-8]: started with pid [27233]
# process[magna/odom2pathmagna-9]: started with pid [27239]
# process[magna/global_frame_tf_magna-10]: started with pid [27242]
# [magna/urdf_spawnermagna-2] process has finished cleanly
# log file: /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/magna-urdf_spawnermagna-2*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=0.0', 'X:=41.3802852039', 'laser_sensor:=False', 'yaw:=1.5707963268', 'robot:=magna']
# started roslaunch server http://ivory.local:46221/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /nebula/distanceEstimator/angle_max: 10.0
#  * /nebula/distanceEstimator/angle_min: -10.0
#  * /nebula/distanceEstimator/scan_topic: /nebula/front_las...
#  * /nebula/front_left_steering_position_controller/joint: front_left_steeri...
#  * /nebula/front_left_steering_position_controller/pid/d: 10.0
#  * /nebula/front_left_steering_position_controller/pid/i: 0.01
#  * /nebula/front_left_steering_position_controller/pid/p: 100.0
#  * /nebula/front_left_steering_position_controller/type: position_controll...
#  * /nebula/front_right_steering_position_controller/joint: front_right_steer...
#  * /nebula/front_right_steering_position_controller/pid/d: 10.0
#  * /nebula/front_right_steering_position_controller/pid/i: 0.01
#  * /nebula/front_right_steering_position_controller/pid/p: 100.0
#  * /nebula/front_right_steering_position_controller/type: position_controll...
#  * /nebula/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /nebula/joint1_velocity_controller/pid/d: 10.0
#  * /nebula/joint1_velocity_controller/pid/i: 0.01
#  * /nebula/joint1_velocity_controller/pid/p: 100.0
#  * /nebula/joint1_velocity_controller/type: velocity_controll...
#  * /nebula/joint2_velocity_controller/joint: back_right_wheel_...
#  * /nebula/joint2_velocity_controller/pid/d: 10.0
#  * /nebula/joint2_velocity_controller/pid/i: 0.01
#  * /nebula/joint2_velocity_controller/pid/p: 100.0
#  * /nebula/joint2_velocity_controller/type: velocity_controll...
#  * /nebula/joint_state_controller/publish_rate: 50
#  * /nebula/joint_state_controller/type: joint_state_contr...
#  * /nebula/robot_description: <?xml version="1....
#  * /nebula/tf_prefix: nebula
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /nebula/
#     base_link2slamodom_tf_nebula (tf/static_transform_publisher)
#     cmdvel2gazebonebula (catvehicle/cmdvel2gazebo.py)
#     controller_spawnernebula (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_nebula (tf/static_transform_publisher)
#     joint_state_publishernebula (joint_state_publisher/joint_state_publisher)
#     odom2pathnebula (catvehicle/odom2path.py)
#     robot_state_publishernebula (robot_state_publisher/robot_state_publisher)
#     urdf_spawnernebula (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[nebula/urdf_spawnernebula-11]: started with pid [27425]
# process[nebula/controller_spawnernebula-12]: started with pid [27426]
# process[nebula/robot_state_publishernebula-13]: started with pid [27427]
# process[nebula/joint_state_publishernebula-14]: started with pid [27428]
# process[nebula/base_link2slamodom_tf_nebula-15]: started with pid [27435]
# process[nebula/cmdvel2gazebonebula-16]: started with pid [27438]
# process[nebula/distanceEstimator-17]: started with pid [27444]
# process[nebula/odom2pathnebula-18]: started with pid [27446]
# process[nebula/global_frame_tf_nebula-19]: started with pid [27456]
# [nebula/urdf_spawnernebula-11] process has finished cleanly
# log file: /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/nebula-urdf_spawnernebula-11*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=0.0', 'X:=-41.3802852039', 'laser_sensor:=False', 'yaw:=4.71238898039', 'robot:=nebula']
# Starting Rosbag record:['rosbag  record -a  -o /home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60 --duration=60 __name:=bagrecorder']
# [INFO] [1603533393.607282]: Rosbag record started
# 1e2a9482-15df-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/roslaunch-ivory-26424.log
# started roslaunch server http://ivory.local:46745/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /magna/constVel: 0.0
#  * /magna/strAngle: 0.0681204300119
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#
# NODES
#   /magna/
#     stepvel_magna (stepvel/stepvel_node)
#
# ROS_MASTER_URI=http://localhost:11311
# process[magna/stepvel_magna-20]: started with pid [28051]
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/stepvel.launch started with run-time arguments ['vel:=0.0', 'robot:=magna', 'strAng:=0.0681204300119']
# Velocity node 0  started.
# 1e2a9482-15df-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/roslaunch-ivory-26424.log
# started roslaunch server http://ivory.local:33805/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /nebula/constVel: 0.0
#  * /nebula/strAngle: 0.0681204300119
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#
# NODES
#   /nebula/
#     stepvel_nebula (stepvel/stepvel_node)
#
# ROS_MASTER_URI=http://localhost:11311
# process[nebula/stepvel_nebula-21]: started with pid [28171]
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/stepvel.launch started with run-time arguments ['vel:=0.0', 'robot:=nebula', 'strAng:=0.0681204300119']
# Velocity node 1  started.
# Start ros-rviz
# SIGINT: Destroying the physics world and terminating the simulation.
# Terminating spawn launches
# [magna/stepvel_magna-20] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/stepvel.launch Terminated.
# [INFO] [1603533486.989927]: Control for vehicle magna terminated
# [magna/global_frame_tf_magna-10] killing on exit
# [magna/odom2pathmagna-9] killing on exit
# [magna/distanceEstimator-8] killing on exit
# [magna/cmdvel2gazebomagna-7] killing on exit
# [magna/base_link2slamodom_tf_magna-6] killing on exit
# [magna/joint_state_publishermagna-5] killing on exit
# [magna/robot_state_publishermagna-4] killing on exit
# [magna/controller_spawnermagna-3] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [nebula/stepvel_nebula-21] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/stepvel.launch Terminated.
# [INFO] [1603533487.894114]: Control for vehicle nebula terminated
# [nebula/global_frame_tf_nebula-19] killing on exit
# [nebula/odom2pathnebula-18] killing on exit
# [nebula/cmdvel2gazebonebula-16] killing on exit
# [nebula/distanceEstimator-17] killing on exit
# [nebula/controller_spawnernebula-12] killing on exit
# [nebula/joint_state_publishernebula-14] killing on exit
# [nebula/base_link2slamodom_tf_nebula-15] killing on exit
# [nebula/robot_state_publishernebula-13] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# Destroying ros-rviz
# Destroying physics world
# Stopping ROSBAG Recorder.
# all processes on machine have died, roslaunch will exit
# Retrieving the latest bag file
# [gazebo-1] process has died [pid 26951, exit code -15, cmd /opt/ros/melodic/lib/gazebo_ros/gzserver -e ode /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/worlds/plane.world __name:=gazebo __log:=/home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/gazebo-1.log].
# log file: /home/ivory/.ros/log/1e2a9482-15df-11eb-9142-144f8af0bf40/gazebo-1*.log
# rosnode kill: (None, None)
# ps -aef  STDOUT:(None, None)
# Retrieving latest bag file
# Bag File Recorded Is: catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34.bag
# mkdir STDOUT:("mkdir: created directory 'catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34'\n", None)
# Renaming GZStat log file [/home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/gz_stats_2020-10-24-02-56-38-619483.txt] to retain bag file information
# mv STDOUT:("renamed '/home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/gz_stats_2020-10-24-02-56-38-619483.txt' -> 'catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34/catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34_gzStats.txt'\n", None)
# Killing roscore
# psutil.Process(pid=26842, name='sh', started='02:55:58')
# [psutil.Process(pid=26843, name='roscore', started='02:55:58'), psutil.Process(pid=26853, name='rosmaster', started='02:55:59'), psutil.Process(pid=26865, name='rosout', started='02:55:59')]
# Attempted to kill child: psutil.Process(pid=26843, name='roscore', started='02:55:58')
# Attempted to kill child: psutil.Process(pid=26853, name='rosmaster', started='02:55:59')
# Attempted to kill child: psutil.Process(pid=26865, name='rosout', started='02:55:59')
# ##### Simulation Terminated #####

# %% [markdown]
# ## Analysis

# %%
bag = C.latesbag()
gz_stat_file = C.gzstatsfile
GZ = gzstats(gz_stat_file)
GZ.dataframe.to_csv(gz_stat_file[0:-4]+".csv")
# Out:
# Retrieving latest bag file
# Bag File Recorded Is: catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34.bag
# mkdir STDOUT:('', None)
# Renaming GZStat log file [catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34/catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34_gzStats.txt] to retain bag file information
# mv STDOUT:('', None)

# %%
b = bagreader(bag)
statistics_file = b.message_by_topic('/statistics')
statistics = pd.read_csv(statistics_file)
fig, ax = bagpy.create_fig(2)
ax[0].scatter(x = 'Time', y = 'dropped_msgs', data =statistics, label = 'No. of Messages Dropped', alpha = 0.5, s = 20, c = '#0f4c5c')
ax[1].scatter(x = 'Time', y = 'delivered_msgs', data =statistics, label = 'No. of Messages Delivered',alpha = 0.5,  s = 20, c = '#772e25')
ax[0].legend(markerscale = 4, fontsize = 20)
ax[1].legend(markerscale = 4, fontsize = 20)
ax[0].set_xlabel('Time')
ax[1].set_xlabel('Time')

fig.show()
# Out:
# [INFO]  Data folder /home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/catvehicle_n_2_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_60_2020-10-24-02-56-34 already exists. Not creating.
# /home/ivory/.local/lib/python2.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
