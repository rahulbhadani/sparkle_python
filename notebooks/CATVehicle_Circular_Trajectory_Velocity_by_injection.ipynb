# %% [markdown]
# # CAT Vehicle circular trajectory replication from Arizona Ring Road Experiment

# %% [markdown]
# In this notebook we conduct 21 car simulation by injecting velocity from FollowerStopper ring road experiment (Test 5)

# %% [markdown]
# ## import required libraries

# %%
import sparkle
import os
from sparkle import lane
from sparkle import api
from sparkle import catvehicle
from sparkle import gzstats
homedir = os.path.expanduser("~")
import uuid
import glob
import bagpy
from bagpy import bagreader
import pandas as pd
import signal
import seaborn as sea
import  time
import math
import numpy as np

# %%
velocity_folder1 = glob.glob("/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/*.csv")
velocity_folder1 =sorted(velocity_folder1)
velocity_folder1
# Out:
# ['/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_01.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_02.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_03.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_04.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_05.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_06.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_07.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_08.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_09.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_10.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_11.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_12.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_13.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_14.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_15.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_16.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_17.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_18.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_19.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_20.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_21.csv']

# %%
velocity_folder = velocity_folder1[17:21] + velocity_folder1[0:17]
velocity_folder
# Out:
# ['/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_18.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_19.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_20.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_21.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_01.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_02.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_03.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_04.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_05.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_06.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_07.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_08.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_09.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_10.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_11.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_12.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_13.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_14.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_15.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_16.csv',
#  '/home/ivory/CyverseData/JmscslgroupData/ARED/2016-07-28/data_by_test/CSVData/test5/test5_17.csv']

# %% [markdown]
# ## declare simulation parameters

# %%
datadir = homedir +"/CyverseData/ProjectSparkle/RTFvsNVehicles"
n_vehicles = 21
include_laser = False
circumference = 260
max_update_rate = 100.0 # for gazebo
time_step = 0.01 # for gazebo
leader_vel = 8.0
log_time = 120.0
unique_runid = str(uuid.uuid4())
description = "Circular Trajectory, Unique run ID = " + unique_runid


# 2.82321111
wb = [2.82321111]

for w in wb:
    print("Wheelbase: {}".format(w))
    sim_config = {"n_vehicles":  n_vehicles, 
                  "include_laser": include_laser, 
                  "circumference": circumference,
                  "max_update_rate": max_update_rate, 
                  "time_step": time_step, 
                  "leader_vel": leader_vel,
                  "log_time": log_time, 
                  "description": description,
                  "package_name": "catvehicle",
                  "logdir": datadir, 
                  "wheelbase": w}

    C = catvehicle(**sim_config)
    C.create()
    C.spawn()
    time.sleep(2)

    C.control(leader_vel=leader_vel, logdir = datadir, control_method = "injector", \
             injection_files = velocity_folder, time_col = "Time", vel_col = "Speed")
    C.rviz(C.package_path + "/config/magna_multi.rviz")
    time.sleep(log_time)
    C.destroy(signal.SIGINT)
# Out:
# Wheelbase: 2.82321111
# ************ Radius of the circle is 41.3802852039 ************
# Theta:0.299199300342 radian.
# Constant Steering Angle:=0.0681204300119
# Sparkle layout instance created.
# Number of CPU on this machine: 8
# PACKAGE NAME BEING EXECUTED IS catvehicle
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# started roslaunch server http://ivory.local:37073/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /gazebo/enable_ros_network: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /
#     gazebo (gazebo_ros/gzserver)
#
# ROS_MASTER_URI=http://localhost:11311
# process[gazebo-1]: started with pid [19222]
# Empty world launched.
# Current  max_update_rate is 100.0
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# 6654feee-15e6-11eb-9142-144f8af0bf40
# ... logging to /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/roslaunch-ivory-18805.log
# started roslaunch server http://ivory.local:41013/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /magna/distanceEstimator/angle_max: 10.0
#  * /magna/distanceEstimator/angle_min: -10.0
#  * /magna/distanceEstimator/scan_topic: /magna/front_lase...
#  * /magna/front_left_steering_position_controller/joint: front_left_steeri...
#  * /magna/front_left_steering_position_controller/pid/d: 10.0
#  * /magna/front_left_steering_position_controller/pid/i: 0.01
#  * /magna/front_left_steering_position_controller/pid/p: 100.0
#  * /magna/front_left_steering_position_controller/type: position_controll...
#  * /magna/front_right_steering_position_controller/joint: front_right_steer...
#  * /magna/front_right_steering_position_controller/pid/d: 10.0
#  * /magna/front_right_steering_position_controller/pid/i: 0.01
#  * /magna/front_right_steering_position_controller/pid/p: 100.0
#  * /magna/front_right_steering_position_controller/type: position_controll...
#  * /magna/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /magna/joint1_velocity_controller/pid/d: 10.0
#  * /magna/joint1_velocity_controller/pid/i: 0.01
#  * /magna/joint1_velocity_controller/pid/p: 100.0
#  * /magna/joint1_velocity_controller/type: velocity_controll...
#  * /magna/joint2_velocity_controller/joint: back_right_wheel_...
#  * /magna/joint2_velocity_controller/pid/d: 10.0
#  * /magna/joint2_velocity_controller/pid/i: 0.01
#  * /magna/joint2_velocity_controller/pid/p: 100.0
#  * /magna/joint2_velocity_controller/type: velocity_controll...
#  * /magna/joint_state_controller/publish_rate: 50
#  * /magna/joint_state_controller/type: joint_state_contr...
#  * /magna/robot_description: <?xml version="1....
#  * /magna/tf_prefix: magna
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /magna/
#     base_link2slamodom_tf_magna (tf/static_transform_publisher)
#     cmdvel2gazebomagna (catvehicle/cmdvel2gazebo.py)
#     controller_spawnermagna (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_magna (tf/static_transform_publisher)
#     joint_state_publishermagna (joint_state_publisher/joint_state_publisher)
#     odom2pathmagna (catvehicle/odom2path.py)
#     robot_state_publishermagna (robot_state_publisher/robot_state_publisher)
#     urdf_spawnermagna (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[magna/urdf_spawnermagna-2]: started with pid [19767]
# process[magna/controller_spawnermagna-3]: started with pid [19769]
# process[magna/robot_state_publishermagna-4]: started with pid [19770]
# process[magna/joint_state_publishermagna-5]: started with pid [19771]
# process[magna/base_link2slamodom_tf_magna-6]: started with pid [19777]
# process[magna/cmdvel2gazebomagna-7]: started with pid [19783]
# process[magna/distanceEstimator-8]: started with pid [19785]
# process[magna/odom2pathmagna-9]: started with pid [19787]
# process[magna/global_frame_tf_magna-10]: started with pid [19793]
# [magna/urdf_spawnermagna-2] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/magna-urdf_spawnermagna-2*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=0.0', 'X:=41.3802852039', 'laser_sensor:=False', 'yaw:=1.5707963268', 'robot:=magna']
# started roslaunch server http://ivory.local:36605/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /nebula/distanceEstimator/angle_max: 10.0
#  * /nebula/distanceEstimator/angle_min: -10.0
#  * /nebula/distanceEstimator/scan_topic: /nebula/front_las...
#  * /nebula/front_left_steering_position_controller/joint: front_left_steeri...
#  * /nebula/front_left_steering_position_controller/pid/d: 10.0
#  * /nebula/front_left_steering_position_controller/pid/i: 0.01
#  * /nebula/front_left_steering_position_controller/pid/p: 100.0
#  * /nebula/front_left_steering_position_controller/type: position_controll...
#  * /nebula/front_right_steering_position_controller/joint: front_right_steer...
#  * /nebula/front_right_steering_position_controller/pid/d: 10.0
#  * /nebula/front_right_steering_position_controller/pid/i: 0.01
#  * /nebula/front_right_steering_position_controller/pid/p: 100.0
#  * /nebula/front_right_steering_position_controller/type: position_controll...
#  * /nebula/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /nebula/joint1_velocity_controller/pid/d: 10.0
#  * /nebula/joint1_velocity_controller/pid/i: 0.01
#  * /nebula/joint1_velocity_controller/pid/p: 100.0
#  * /nebula/joint1_velocity_controller/type: velocity_controll...
#  * /nebula/joint2_velocity_controller/joint: back_right_wheel_...
#  * /nebula/joint2_velocity_controller/pid/d: 10.0
#  * /nebula/joint2_velocity_controller/pid/i: 0.01
#  * /nebula/joint2_velocity_controller/pid/p: 100.0
#  * /nebula/joint2_velocity_controller/type: velocity_controll...
#  * /nebula/joint_state_controller/publish_rate: 50
#  * /nebula/joint_state_controller/type: joint_state_contr...
#  * /nebula/robot_description: <?xml version="1....
#  * /nebula/tf_prefix: nebula
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /nebula/
#     base_link2slamodom_tf_nebula (tf/static_transform_publisher)
#     cmdvel2gazebonebula (catvehicle/cmdvel2gazebo.py)
#     controller_spawnernebula (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_nebula (tf/static_transform_publisher)
#     joint_state_publishernebula (joint_state_publisher/joint_state_publisher)
#     odom2pathnebula (catvehicle/odom2path.py)
#     robot_state_publishernebula (robot_state_publisher/robot_state_publisher)
#     urdf_spawnernebula (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[nebula/urdf_spawnernebula-11]: started with pid [19985]
# process[nebula/controller_spawnernebula-12]: started with pid [19986]
# process[nebula/robot_state_publishernebula-13]: started with pid [19987]
# process[nebula/joint_state_publishernebula-14]: started with pid [19988]
# process[nebula/base_link2slamodom_tf_nebula-15]: started with pid [19994]
# process[nebula/cmdvel2gazebonebula-16]: started with pid [19997]
# process[nebula/distanceEstimator-17]: started with pid [20002]
# process[nebula/odom2pathnebula-18]: started with pid [20005]
# process[nebula/global_frame_tf_nebula-19]: started with pid [20013]
# [nebula/urdf_spawnernebula-11] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/nebula-urdf_spawnernebula-11*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=12.1970531824', 'X:=39.5418752365', 'laser_sensor:=False', 'yaw:=1.86999562714', 'robot:=nebula']
# started roslaunch server http://ivory.local:35537/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /calista/distanceEstimator/angle_max: 10.0
#  * /calista/distanceEstimator/angle_min: -10.0
#  * /calista/distanceEstimator/scan_topic: /calista/front_la...
#  * /calista/front_left_steering_position_controller/joint: front_left_steeri...
#  * /calista/front_left_steering_position_controller/pid/d: 10.0
#  * /calista/front_left_steering_position_controller/pid/i: 0.01
#  * /calista/front_left_steering_position_controller/pid/p: 100.0
#  * /calista/front_left_steering_position_controller/type: position_controll...
#  * /calista/front_right_steering_position_controller/joint: front_right_steer...
#  * /calista/front_right_steering_position_controller/pid/d: 10.0
#  * /calista/front_right_steering_position_controller/pid/i: 0.01
#  * /calista/front_right_steering_position_controller/pid/p: 100.0
#  * /calista/front_right_steering_position_controller/type: position_controll...
#  * /calista/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /calista/joint1_velocity_controller/pid/d: 10.0
#  * /calista/joint1_velocity_controller/pid/i: 0.01
#  * /calista/joint1_velocity_controller/pid/p: 100.0
#  * /calista/joint1_velocity_controller/type: velocity_controll...
#  * /calista/joint2_velocity_controller/joint: back_right_wheel_...
#  * /calista/joint2_velocity_controller/pid/d: 10.0
#  * /calista/joint2_velocity_controller/pid/i: 0.01
#  * /calista/joint2_velocity_controller/pid/p: 100.0
#  * /calista/joint2_velocity_controller/type: velocity_controll...
#  * /calista/joint_state_controller/publish_rate: 50
#  * /calista/joint_state_controller/type: joint_state_contr...
#  * /calista/robot_description: <?xml version="1....
#  * /calista/tf_prefix: calista
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /calista/
#     base_link2slamodom_tf_calista (tf/static_transform_publisher)
#     cmdvel2gazebocalista (catvehicle/cmdvel2gazebo.py)
#     controller_spawnercalista (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_calista (tf/static_transform_publisher)
#     joint_state_publishercalista (joint_state_publisher/joint_state_publisher)
#     odom2pathcalista (catvehicle/odom2path.py)
#     robot_state_publishercalista (robot_state_publisher/robot_state_publisher)
#     urdf_spawnercalista (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[calista/urdf_spawnercalista-20]: started with pid [20185]
# process[calista/controller_spawnercalista-21]: started with pid [20186]
# process[calista/robot_state_publishercalista-22]: started with pid [20187]
# process[calista/joint_state_publishercalista-23]: started with pid [20188]
# process[calista/base_link2slamodom_tf_calista-24]: started with pid [20193]
# process[calista/cmdvel2gazebocalista-25]: started with pid [20201]
# process[calista/distanceEstimator-26]: started with pid [20204]
# process[calista/odom2pathcalista-27]: started with pid [20208]
# process[calista/global_frame_tf_calista-28]: started with pid [20214]
# [calista/urdf_spawnercalista-20] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/calista-urdf_spawnercalista-20*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=23.3103446637', 'X:=34.1899961277', 'laser_sensor:=False', 'yaw:=2.16919492748', 'robot:=calista']
# started roslaunch server http://ivory.local:35875/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /proxima/distanceEstimator/angle_max: 10.0
#  * /proxima/distanceEstimator/angle_min: -10.0
#  * /proxima/distanceEstimator/scan_topic: /proxima/front_la...
#  * /proxima/front_left_steering_position_controller/joint: front_left_steeri...
#  * /proxima/front_left_steering_position_controller/pid/d: 10.0
#  * /proxima/front_left_steering_position_controller/pid/i: 0.01
#  * /proxima/front_left_steering_position_controller/pid/p: 100.0
#  * /proxima/front_left_steering_position_controller/type: position_controll...
#  * /proxima/front_right_steering_position_controller/joint: front_right_steer...
#  * /proxima/front_right_steering_position_controller/pid/d: 10.0
#  * /proxima/front_right_steering_position_controller/pid/i: 0.01
#  * /proxima/front_right_steering_position_controller/pid/p: 100.0
#  * /proxima/front_right_steering_position_controller/type: position_controll...
#  * /proxima/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /proxima/joint1_velocity_controller/pid/d: 10.0
#  * /proxima/joint1_velocity_controller/pid/i: 0.01
#  * /proxima/joint1_velocity_controller/pid/p: 100.0
#  * /proxima/joint1_velocity_controller/type: velocity_controll...
#  * /proxima/joint2_velocity_controller/joint: back_right_wheel_...
#  * /proxima/joint2_velocity_controller/pid/d: 10.0
#  * /proxima/joint2_velocity_controller/pid/i: 0.01
#  * /proxima/joint2_velocity_controller/pid/p: 100.0
#  * /proxima/joint2_velocity_controller/type: velocity_controll...
#  * /proxima/joint_state_controller/publish_rate: 50
#  * /proxima/joint_state_controller/type: joint_state_contr...
#  * /proxima/robot_description: <?xml version="1....
#  * /proxima/tf_prefix: proxima
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /proxima/
#     base_link2slamodom_tf_proxima (tf/static_transform_publisher)
#     cmdvel2gazeboproxima (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerproxima (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_proxima (tf/static_transform_publisher)
#     joint_state_publisherproxima (joint_state_publisher/joint_state_publisher)
#     odom2pathproxima (catvehicle/odom2path.py)
#     robot_state_publisherproxima (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerproxima (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[proxima/urdf_spawnerproxima-29]: started with pid [20401]
# process[proxima/controller_spawnerproxima-30]: started with pid [20402]
# process[proxima/robot_state_publisherproxima-31]: started with pid [20403]
# process[proxima/joint_state_publisherproxima-32]: started with pid [20404]
# process[proxima/base_link2slamodom_tf_proxima-33]: started with pid [20410]
# process[proxima/cmdvel2gazeboproxima-34]: started with pid [20414]
# process[proxima/distanceEstimator-35]: started with pid [20420]
# process[proxima/odom2pathproxima-36]: started with pid [20423]
# process[proxima/global_frame_tf_proxima-37]: started with pid [20429]
# [proxima/urdf_spawnerproxima-29] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/proxima-urdf_spawnerproxima-29*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=32.3524097259', 'X:=25.8001858226', 'laser_sensor:=False', 'yaw:=2.46839422782', 'robot:=proxima']
# started roslaunch server http://ivory.local:36263/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#  * /zel/distanceEstimator/angle_max: 10.0
#  * /zel/distanceEstimator/angle_min: -10.0
#  * /zel/distanceEstimator/scan_topic: /zel/front_laser_...
#  * /zel/front_left_steering_position_controller/joint: front_left_steeri...
#  * /zel/front_left_steering_position_controller/pid/d: 10.0
#  * /zel/front_left_steering_position_controller/pid/i: 0.01
#  * /zel/front_left_steering_position_controller/pid/p: 100.0
#  * /zel/front_left_steering_position_controller/type: position_controll...
#  * /zel/front_right_steering_position_controller/joint: front_right_steer...
#  * /zel/front_right_steering_position_controller/pid/d: 10.0
#  * /zel/front_right_steering_position_controller/pid/i: 0.01
#  * /zel/front_right_steering_position_controller/pid/p: 100.0
#  * /zel/front_right_steering_position_controller/type: position_controll...
#  * /zel/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /zel/joint1_velocity_controller/pid/d: 10.0
#  * /zel/joint1_velocity_controller/pid/i: 0.01
#  * /zel/joint1_velocity_controller/pid/p: 100.0
#  * /zel/joint1_velocity_controller/type: velocity_controll...
#  * /zel/joint2_velocity_controller/joint: back_right_wheel_...
#  * /zel/joint2_velocity_controller/pid/d: 10.0
#  * /zel/joint2_velocity_controller/pid/i: 0.01
#  * /zel/joint2_velocity_controller/pid/p: 100.0
#  * /zel/joint2_velocity_controller/type: velocity_controll...
#  * /zel/joint_state_controller/publish_rate: 50
#  * /zel/joint_state_controller/type: joint_state_contr...
#  * /zel/robot_description: <?xml version="1....
#  * /zel/tf_prefix: zel
#
# NODES
#   /zel/
#     base_link2slamodom_tf_zel (tf/static_transform_publisher)
#     cmdvel2gazebozel (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerzel (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_zel (tf/static_transform_publisher)
#     joint_state_publisherzel (joint_state_publisher/joint_state_publisher)
#     odom2pathzel (catvehicle/odom2path.py)
#     robot_state_publisherzel (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerzel (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[zel/urdf_spawnerzel-38]: started with pid [20613]
# process[zel/controller_spawnerzel-39]: started with pid [20614]
# process[zel/robot_state_publisherzel-40]: started with pid [20616]
# process[zel/joint_state_publisherzel-41]: started with pid [20618]
# process[zel/base_link2slamodom_tf_zel-42]: started with pid [20623]
# process[zel/cmdvel2gazebozel-43]: started with pid [20626]
# process[zel/distanceEstimator-44]: started with pid [20632]
# process[zel/odom2pathzel-45]: started with pid [20636]
# process[zel/global_frame_tf_zel-46]: started with pid [20642]
# [zel/urdf_spawnerzel-38] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/zel-urdf_spawnerzel-38*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=38.5198212077', 'X:=15.117915785', 'laser_sensor:=False', 'yaw:=2.76759352816', 'robot:=zel']
# started roslaunch server http://ivory.local:33069/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#  * /zephyr/distanceEstimator/angle_max: 10.0
#  * /zephyr/distanceEstimator/angle_min: -10.0
#  * /zephyr/distanceEstimator/scan_topic: /zephyr/front_las...
#  * /zephyr/front_left_steering_position_controller/joint: front_left_steeri...
#  * /zephyr/front_left_steering_position_controller/pid/d: 10.0
#  * /zephyr/front_left_steering_position_controller/pid/i: 0.01
#  * /zephyr/front_left_steering_position_controller/pid/p: 100.0
#  * /zephyr/front_left_steering_position_controller/type: position_controll...
#  * /zephyr/front_right_steering_position_controller/joint: front_right_steer...
#  * /zephyr/front_right_steering_position_controller/pid/d: 10.0
#  * /zephyr/front_right_steering_position_controller/pid/i: 0.01
#  * /zephyr/front_right_steering_position_controller/pid/p: 100.0
#  * /zephyr/front_right_steering_position_controller/type: position_controll...
#  * /zephyr/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /zephyr/joint1_velocity_controller/pid/d: 10.0
#  * /zephyr/joint1_velocity_controller/pid/i: 0.01
#  * /zephyr/joint1_velocity_controller/pid/p: 100.0
#  * /zephyr/joint1_velocity_controller/type: velocity_controll...
#  * /zephyr/joint2_velocity_controller/joint: back_right_wheel_...
#  * /zephyr/joint2_velocity_controller/pid/d: 10.0
#  * /zephyr/joint2_velocity_controller/pid/i: 0.01
#  * /zephyr/joint2_velocity_controller/pid/p: 100.0
#  * /zephyr/joint2_velocity_controller/type: velocity_controll...
#  * /zephyr/joint_state_controller/publish_rate: 50
#  * /zephyr/joint_state_controller/type: joint_state_contr...
#  * /zephyr/robot_description: <?xml version="1....
#  * /zephyr/tf_prefix: zephyr
#
# NODES
#   /zephyr/
#     base_link2slamodom_tf_zephyr (tf/static_transform_publisher)
#     cmdvel2gazebozephyr (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerzephyr (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_zephyr (tf/static_transform_publisher)
#     joint_state_publisherzephyr (joint_state_publisher/joint_state_publisher)
#     odom2pathzephyr (catvehicle/odom2path.py)
#     robot_state_publisherzephyr (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerzephyr (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[zephyr/urdf_spawnerzephyr-47]: started with pid [20917]
# process[zephyr/controller_spawnerzephyr-48]: started with pid [20919]
# process[zephyr/robot_state_publisherzephyr-49]: started with pid [20920]
# process[zephyr/joint_state_publisherzephyr-50]: started with pid [20921]
# process[zephyr/base_link2slamodom_tf_zephyr-51]: started with pid [20929]
# process[zephyr/cmdvel2gazebozephyr-52]: started with pid [20931]
# process[zephyr/distanceEstimator-53]: started with pid [20937]
# process[zephyr/odom2pathzephyr-54]: started with pid [20947]
# process[zephyr/global_frame_tf_zephyr-55]: started with pid [20950]
# [zephyr/urdf_spawnerzephyr-47] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/zephyr-urdf_spawnerzephyr-47*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=41.2645775338', 'X:=3.09235258592', 'laser_sensor:=False', 'yaw:=3.0667928285', 'robot:=zephyr']
# started roslaunch server http://ivory.local:36617/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /centauri/distanceEstimator/angle_max: 10.0
#  * /centauri/distanceEstimator/angle_min: -10.0
#  * /centauri/distanceEstimator/scan_topic: /centauri/front_l...
#  * /centauri/front_left_steering_position_controller/joint: front_left_steeri...
#  * /centauri/front_left_steering_position_controller/pid/d: 10.0
#  * /centauri/front_left_steering_position_controller/pid/i: 0.01
#  * /centauri/front_left_steering_position_controller/pid/p: 100.0
#  * /centauri/front_left_steering_position_controller/type: position_controll...
#  * /centauri/front_right_steering_position_controller/joint: front_right_steer...
#  * /centauri/front_right_steering_position_controller/pid/d: 10.0
#  * /centauri/front_right_steering_position_controller/pid/i: 0.01
#  * /centauri/front_right_steering_position_controller/pid/p: 100.0
#  * /centauri/front_right_steering_position_controller/type: position_controll...
#  * /centauri/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /centauri/joint1_velocity_controller/pid/d: 10.0
#  * /centauri/joint1_velocity_controller/pid/i: 0.01
#  * /centauri/joint1_velocity_controller/pid/p: 100.0
#  * /centauri/joint1_velocity_controller/type: velocity_controll...
#  * /centauri/joint2_velocity_controller/joint: back_right_wheel_...
#  * /centauri/joint2_velocity_controller/pid/d: 10.0
#  * /centauri/joint2_velocity_controller/pid/i: 0.01
#  * /centauri/joint2_velocity_controller/pid/p: 100.0
#  * /centauri/joint2_velocity_controller/type: velocity_controll...
#  * /centauri/joint_state_controller/publish_rate: 50
#  * /centauri/joint_state_controller/type: joint_state_contr...
#  * /centauri/robot_description: <?xml version="1....
#  * /centauri/tf_prefix: centauri
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /centauri/
#     base_link2slamodom_tf_centauri (tf/static_transform_publisher)
#     cmdvel2gazebocentauri (catvehicle/cmdvel2gazebo.py)
#     controller_spawnercentauri (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_centauri (tf/static_transform_publisher)
#     joint_state_publishercentauri (joint_state_publisher/joint_state_publisher)
#     odom2pathcentauri (catvehicle/odom2path.py)
#     robot_state_publishercentauri (robot_state_publisher/robot_state_publisher)
#     urdf_spawnercentauri (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[centauri/urdf_spawnercentauri-56]: started with pid [21131]
# process[centauri/controller_spawnercentauri-57]: started with pid [21132]
# process[centauri/robot_state_publishercentauri-58]: started with pid [21134]
# process[centauri/joint_state_publishercentauri-59]: started with pid [21135]
# process[centauri/base_link2slamodom_tf_centauri-60]: started with pid [21141]
# process[centauri/cmdvel2gazebocentauri-61]: started with pid [21144]
# process[centauri/distanceEstimator-62]: started with pid [21152]
# process[centauri/odom2pathcentauri-63]: started with pid [21159]
# process[centauri/global_frame_tf_centauri-64]: started with pid [21162]
# [centauri/urdf_spawnercentauri-56] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/centauri-urdf_spawnercentauri-56*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=40.3427950593', 'X:=-9.20797971095', 'laser_sensor:=False', 'yaw:=3.36599212885', 'robot:=centauri']
# started roslaunch server http://ivory.local:33063/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#  * /zenith/distanceEstimator/angle_max: 10.0
#  * /zenith/distanceEstimator/angle_min: -10.0
#  * /zenith/distanceEstimator/scan_topic: /zenith/front_las...
#  * /zenith/front_left_steering_position_controller/joint: front_left_steeri...
#  * /zenith/front_left_steering_position_controller/pid/d: 10.0
#  * /zenith/front_left_steering_position_controller/pid/i: 0.01
#  * /zenith/front_left_steering_position_controller/pid/p: 100.0
#  * /zenith/front_left_steering_position_controller/type: position_controll...
#  * /zenith/front_right_steering_position_controller/joint: front_right_steer...
#  * /zenith/front_right_steering_position_controller/pid/d: 10.0
#  * /zenith/front_right_steering_position_controller/pid/i: 0.01
#  * /zenith/front_right_steering_position_controller/pid/p: 100.0
#  * /zenith/front_right_steering_position_controller/type: position_controll...
#  * /zenith/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /zenith/joint1_velocity_controller/pid/d: 10.0
#  * /zenith/joint1_velocity_controller/pid/i: 0.01
#  * /zenith/joint1_velocity_controller/pid/p: 100.0
#  * /zenith/joint1_velocity_controller/type: velocity_controll...
#  * /zenith/joint2_velocity_controller/joint: back_right_wheel_...
#  * /zenith/joint2_velocity_controller/pid/d: 10.0
#  * /zenith/joint2_velocity_controller/pid/i: 0.01
#  * /zenith/joint2_velocity_controller/pid/p: 100.0
#  * /zenith/joint2_velocity_controller/type: velocity_controll...
#  * /zenith/joint_state_controller/publish_rate: 50
#  * /zenith/joint_state_controller/type: joint_state_contr...
#  * /zenith/robot_description: <?xml version="1....
#  * /zenith/tf_prefix: zenith
#
# NODES
#   /zenith/
#     base_link2slamodom_tf_zenith (tf/static_transform_publisher)
#     cmdvel2gazebozenith (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerzenith (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_zenith (tf/static_transform_publisher)
#     joint_state_publisherzenith (joint_state_publisher/joint_state_publisher)
#     odom2pathzenith (catvehicle/odom2path.py)
#     robot_state_publisherzenith (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerzenith (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[zenith/urdf_spawnerzenith-65]: started with pid [21306]
# process[zenith/controller_spawnerzenith-66]: started with pid [21307]
# process[zenith/robot_state_publisherzenith-67]: started with pid [21308]
# process[zenith/joint_state_publisherzenith-68]: started with pid [21310]
# process[zenith/base_link2slamodom_tf_zenith-69]: started with pid [21316]
# process[zenith/cmdvel2gazebozenith-70]: started with pid [21319]
# process[zenith/distanceEstimator-71]: started with pid [21329]
# process[zenith/odom2pathzenith-72]: started with pid [21331]
# process[zenith/global_frame_tf_zenith-73]: started with pid [21339]
# [zenith/urdf_spawnerzenith-65] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/zenith-urdf_spawnerzenith-65*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=35.8363782024', 'X:=-20.690142602', 'laser_sensor:=False', 'yaw:=3.66519142919', 'robot:=zenith']
# started roslaunch server http://ivory.local:42225/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /europa/distanceEstimator/angle_max: 10.0
#  * /europa/distanceEstimator/angle_min: -10.0
#  * /europa/distanceEstimator/scan_topic: /europa/front_las...
#  * /europa/front_left_steering_position_controller/joint: front_left_steeri...
#  * /europa/front_left_steering_position_controller/pid/d: 10.0
#  * /europa/front_left_steering_position_controller/pid/i: 0.01
#  * /europa/front_left_steering_position_controller/pid/p: 100.0
#  * /europa/front_left_steering_position_controller/type: position_controll...
#  * /europa/front_right_steering_position_controller/joint: front_right_steer...
#  * /europa/front_right_steering_position_controller/pid/d: 10.0
#  * /europa/front_right_steering_position_controller/pid/i: 0.01
#  * /europa/front_right_steering_position_controller/pid/p: 100.0
#  * /europa/front_right_steering_position_controller/type: position_controll...
#  * /europa/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /europa/joint1_velocity_controller/pid/d: 10.0
#  * /europa/joint1_velocity_controller/pid/i: 0.01
#  * /europa/joint1_velocity_controller/pid/p: 100.0
#  * /europa/joint1_velocity_controller/type: velocity_controll...
#  * /europa/joint2_velocity_controller/joint: back_right_wheel_...
#  * /europa/joint2_velocity_controller/pid/d: 10.0
#  * /europa/joint2_velocity_controller/pid/i: 0.01
#  * /europa/joint2_velocity_controller/pid/p: 100.0
#  * /europa/joint2_velocity_controller/type: velocity_controll...
#  * /europa/joint_state_controller/publish_rate: 50
#  * /europa/joint_state_controller/type: joint_state_contr...
#  * /europa/robot_description: <?xml version="1....
#  * /europa/tf_prefix: europa
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /europa/
#     base_link2slamodom_tf_europa (tf/static_transform_publisher)
#     cmdvel2gazeboeuropa (catvehicle/cmdvel2gazebo.py)
#     controller_spawnereuropa (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_europa (tf/static_transform_publisher)
#     joint_state_publishereuropa (joint_state_publisher/joint_state_publisher)
#     odom2patheuropa (catvehicle/odom2path.py)
#     robot_state_publishereuropa (robot_state_publisher/robot_state_publisher)
#     urdf_spawnereuropa (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[europa/urdf_spawnereuropa-74]: started with pid [21474]
# process[europa/controller_spawnereuropa-75]: started with pid [21475]
# process[europa/robot_state_publishereuropa-76]: started with pid [21476]
# process[europa/joint_state_publishereuropa-77]: started with pid [21477]
# process[europa/base_link2slamodom_tf_europa-78]: started with pid [21483]
# process[europa/cmdvel2gazeboeuropa-79]: started with pid [21490]
# process[europa/distanceEstimator-80]: started with pid [21496]
# process[europa/odom2patheuropa-81]: started with pid [21498]
# process[europa/global_frame_tf_europa-82]: started with pid [21506]
# [europa/urdf_spawnereuropa-74] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/europa-urdf_spawnereuropa-74*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=28.1457418769', 'X:=-30.3338955256', 'laser_sensor:=False', 'yaw:=3.96439072953', 'robot:=europa']
# started roslaunch server http://ivory.local:41745/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /elara/distanceEstimator/angle_max: 10.0
#  * /elara/distanceEstimator/angle_min: -10.0
#  * /elara/distanceEstimator/scan_topic: /elara/front_lase...
#  * /elara/front_left_steering_position_controller/joint: front_left_steeri...
#  * /elara/front_left_steering_position_controller/pid/d: 10.0
#  * /elara/front_left_steering_position_controller/pid/i: 0.01
#  * /elara/front_left_steering_position_controller/pid/p: 100.0
#  * /elara/front_left_steering_position_controller/type: position_controll...
#  * /elara/front_right_steering_position_controller/joint: front_right_steer...
#  * /elara/front_right_steering_position_controller/pid/d: 10.0
#  * /elara/front_right_steering_position_controller/pid/i: 0.01
#  * /elara/front_right_steering_position_controller/pid/p: 100.0
#  * /elara/front_right_steering_position_controller/type: position_controll...
#  * /elara/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /elara/joint1_velocity_controller/pid/d: 10.0
#  * /elara/joint1_velocity_controller/pid/i: 0.01
#  * /elara/joint1_velocity_controller/pid/p: 100.0
#  * /elara/joint1_velocity_controller/type: velocity_controll...
#  * /elara/joint2_velocity_controller/joint: back_right_wheel_...
#  * /elara/joint2_velocity_controller/pid/d: 10.0
#  * /elara/joint2_velocity_controller/pid/i: 0.01
#  * /elara/joint2_velocity_controller/pid/p: 100.0
#  * /elara/joint2_velocity_controller/type: velocity_controll...
#  * /elara/joint_state_controller/publish_rate: 50
#  * /elara/joint_state_controller/type: joint_state_contr...
#  * /elara/robot_description: <?xml version="1....
#  * /elara/tf_prefix: elara
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /elara/
#     base_link2slamodom_tf_elara (tf/static_transform_publisher)
#     cmdvel2gazeboelara (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerelara (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_elara (tf/static_transform_publisher)
#     joint_state_publisherelara (joint_state_publisher/joint_state_publisher)
#     odom2pathelara (catvehicle/odom2path.py)
#     robot_state_publisherelara (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerelara (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[elara/urdf_spawnerelara-83]: started with pid [21643]
# process[elara/controller_spawnerelara-84]: started with pid [21644]
# process[elara/robot_state_publisherelara-85]: started with pid [21645]
# process[elara/joint_state_publisherelara-86]: started with pid [21647]
# process[elara/base_link2slamodom_tf_elara-87]: started with pid [21653]
# process[elara/cmdvel2gazeboelara-88]: started with pid [21661]
# process[elara/distanceEstimator-89]: started with pid [21663]
# process[elara/odom2pathelara-90]: started with pid [21665]
# process[elara/global_frame_tf_elara-91]: started with pid [21668]
# [elara/urdf_spawnerelara-83] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/elara-urdf_spawnerelara-83*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=17.95423287', 'X:=-37.2823487136', 'laser_sensor:=False', 'yaw:=4.26359002987', 'robot:=elara']
# started roslaunch server http://ivory.local:41399/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /herse/distanceEstimator/angle_max: 10.0
#  * /herse/distanceEstimator/angle_min: -10.0
#  * /herse/distanceEstimator/scan_topic: /herse/front_lase...
#  * /herse/front_left_steering_position_controller/joint: front_left_steeri...
#  * /herse/front_left_steering_position_controller/pid/d: 10.0
#  * /herse/front_left_steering_position_controller/pid/i: 0.01
#  * /herse/front_left_steering_position_controller/pid/p: 100.0
#  * /herse/front_left_steering_position_controller/type: position_controll...
#  * /herse/front_right_steering_position_controller/joint: front_right_steer...
#  * /herse/front_right_steering_position_controller/pid/d: 10.0
#  * /herse/front_right_steering_position_controller/pid/i: 0.01
#  * /herse/front_right_steering_position_controller/pid/p: 100.0
#  * /herse/front_right_steering_position_controller/type: position_controll...
#  * /herse/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /herse/joint1_velocity_controller/pid/d: 10.0
#  * /herse/joint1_velocity_controller/pid/i: 0.01
#  * /herse/joint1_velocity_controller/pid/p: 100.0
#  * /herse/joint1_velocity_controller/type: velocity_controll...
#  * /herse/joint2_velocity_controller/joint: back_right_wheel_...
#  * /herse/joint2_velocity_controller/pid/d: 10.0
#  * /herse/joint2_velocity_controller/pid/i: 0.01
#  * /herse/joint2_velocity_controller/pid/p: 100.0
#  * /herse/joint2_velocity_controller/type: velocity_controll...
#  * /herse/joint_state_controller/publish_rate: 50
#  * /herse/joint_state_controller/type: joint_state_contr...
#  * /herse/robot_description: <?xml version="1....
#  * /herse/tf_prefix: herse
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /herse/
#     base_link2slamodom_tf_herse (tf/static_transform_publisher)
#     cmdvel2gazeboherse (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerherse (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_herse (tf/static_transform_publisher)
#     joint_state_publisherherse (joint_state_publisher/joint_state_publisher)
#     odom2pathherse (catvehicle/odom2path.py)
#     robot_state_publisherherse (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerherse (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[herse/urdf_spawnerherse-92]: started with pid [21804]
# process[herse/controller_spawnerherse-93]: started with pid [21805]
# process[herse/robot_state_publisherherse-94]: started with pid [21806]
# process[herse/joint_state_publisherherse-95]: started with pid [21808]
# process[herse/base_link2slamodom_tf_herse-96]: started with pid [21814]
# process[herse/cmdvel2gazeboherse-97]: started with pid [21816]
# process[herse/distanceEstimator-98]: started with pid [21822]
# process[herse/odom2pathherse-99]: started with pid [21826]
# process[herse/global_frame_tf_herse-100]: started with pid [21834]
# [herse/urdf_spawnerherse-92] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/herse-urdf_spawnerherse-92*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=6.1674114818', 'X:=-40.9181016076', 'laser_sensor:=False', 'yaw:=4.56278933021', 'robot:=herse']
# started roslaunch server http://ivory.local:45653/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /thebe/distanceEstimator/angle_max: 10.0
#  * /thebe/distanceEstimator/angle_min: -10.0
#  * /thebe/distanceEstimator/scan_topic: /thebe/front_lase...
#  * /thebe/front_left_steering_position_controller/joint: front_left_steeri...
#  * /thebe/front_left_steering_position_controller/pid/d: 10.0
#  * /thebe/front_left_steering_position_controller/pid/i: 0.01
#  * /thebe/front_left_steering_position_controller/pid/p: 100.0
#  * /thebe/front_left_steering_position_controller/type: position_controll...
#  * /thebe/front_right_steering_position_controller/joint: front_right_steer...
#  * /thebe/front_right_steering_position_controller/pid/d: 10.0
#  * /thebe/front_right_steering_position_controller/pid/i: 0.01
#  * /thebe/front_right_steering_position_controller/pid/p: 100.0
#  * /thebe/front_right_steering_position_controller/type: position_controll...
#  * /thebe/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /thebe/joint1_velocity_controller/pid/d: 10.0
#  * /thebe/joint1_velocity_controller/pid/i: 0.01
#  * /thebe/joint1_velocity_controller/pid/p: 100.0
#  * /thebe/joint1_velocity_controller/type: velocity_controll...
#  * /thebe/joint2_velocity_controller/joint: back_right_wheel_...
#  * /thebe/joint2_velocity_controller/pid/d: 10.0
#  * /thebe/joint2_velocity_controller/pid/i: 0.01
#  * /thebe/joint2_velocity_controller/pid/p: 100.0
#  * /thebe/joint2_velocity_controller/type: velocity_controll...
#  * /thebe/joint_state_controller/publish_rate: 50
#  * /thebe/joint_state_controller/type: joint_state_contr...
#  * /thebe/robot_description: <?xml version="1....
#  * /thebe/tf_prefix: thebe
#  * /use_sim_time: True
#
# NODES
#   /thebe/
#     base_link2slamodom_tf_thebe (tf/static_transform_publisher)
#     cmdvel2gazebothebe (catvehicle/cmdvel2gazebo.py)
#     controller_spawnerthebe (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_thebe (tf/static_transform_publisher)
#     joint_state_publisherthebe (joint_state_publisher/joint_state_publisher)
#     odom2paththebe (catvehicle/odom2path.py)
#     robot_state_publisherthebe (robot_state_publisher/robot_state_publisher)
#     urdf_spawnerthebe (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[thebe/urdf_spawnerthebe-101]: started with pid [21968]
# process[thebe/controller_spawnerthebe-102]: started with pid [21969]
# process[thebe/robot_state_publisherthebe-103]: started with pid [21970]
# process[thebe/joint_state_publisherthebe-104]: started with pid [21972]
# process[thebe/base_link2slamodom_tf_thebe-105]: started with pid [21979]
# process[thebe/cmdvel2gazebothebe-106]: started with pid [21981]
# process[thebe/distanceEstimator-107]: started with pid [21989]
# process[thebe/odom2paththebe-108]: started with pid [21992]
# process[thebe/global_frame_tf_thebe-109]: started with pid [21998]
# [thebe/urdf_spawnerthebe-101] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/thebe-urdf_spawnerthebe-101*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=-6.16741148181', 'X:=-40.9181016076', 'laser_sensor:=False', 'yaw:=4.86198863056', 'robot:=thebe']
# started roslaunch server http://ivory.local:35159/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /metis/distanceEstimator/angle_max: 10.0
#  * /metis/distanceEstimator/angle_min: -10.0
#  * /metis/distanceEstimator/scan_topic: /metis/front_lase...
#  * /metis/front_left_steering_position_controller/joint: front_left_steeri...
#  * /metis/front_left_steering_position_controller/pid/d: 10.0
#  * /metis/front_left_steering_position_controller/pid/i: 0.01
#  * /metis/front_left_steering_position_controller/pid/p: 100.0
#  * /metis/front_left_steering_position_controller/type: position_controll...
#  * /metis/front_right_steering_position_controller/joint: front_right_steer...
#  * /metis/front_right_steering_position_controller/pid/d: 10.0
#  * /metis/front_right_steering_position_controller/pid/i: 0.01
#  * /metis/front_right_steering_position_controller/pid/p: 100.0
#  * /metis/front_right_steering_position_controller/type: position_controll...
#  * /metis/joint1_velocity_controller/joint: back_left_wheel_j...
#  * /metis/joint1_velocity_controller/pid/d: 10.0
#  * /metis/joint1_velocity_controller/pid/i: 0.01
#  * /metis/joint1_velocity_controller/pid/p: 100.0
#  * /metis/joint1_velocity_controller/type: velocity_controll...
#  * /metis/joint2_velocity_controller/joint: back_right_wheel_...
#  * /metis/joint2_velocity_controller/pid/d: 10.0
#  * /metis/joint2_velocity_controller/pid/i: 0.01
#  * /metis/joint2_velocity_controller/pid/p: 100.0
#  * /metis/joint2_velocity_controller/type: velocity_controll...
#  * /metis/joint_state_controller/publish_rate: 50
#  * /metis/joint_state_controller/type: joint_state_contr...
#  * /metis/robot_description: <?xml version="1....
#  * /metis/tf_prefix: metis
#  * /rosdistro: melodic
#  * /rosversion: 1.14.9
#  * /use_sim_time: True
#
# NODES
#   /metis/
#     base_link2slamodom_tf_metis (tf/static_transform_publisher)
#     cmdvel2gazebometis (catvehicle/cmdvel2gazebo.py)
#     controller_spawnermetis (controller_manager/spawner)
#     distanceEstimator (catvehicle/distanceEstimator)
#     global_frame_tf_metis (tf/static_transform_publisher)
#     joint_state_publishermetis (joint_state_publisher/joint_state_publisher)
#     odom2pathmetis (catvehicle/odom2path.py)
#     robot_state_publishermetis (robot_state_publisher/robot_state_publisher)
#     urdf_spawnermetis (gazebo_ros/spawn_model)
#
# ROS_MASTER_URI=http://localhost:11311
# process[metis/urdf_spawnermetis-110]: started with pid [22146]
# process[metis/controller_spawnermetis-111]: started with pid [22152]
# process[metis/robot_state_publishermetis-112]: started with pid [22155]
# process[metis/joint_state_publishermetis-113]: started with pid [22162]
# process[metis/base_link2slamodom_tf_metis-114]: started with pid [22165]
# process[metis/cmdvel2gazebometis-115]: started with pid [22169]
# process[metis/distanceEstimator-116]: started with pid [22176]
# process[metis/odom2pathmetis-117]: started with pid [22179]
# process[metis/global_frame_tf_metis-118]: started with pid [22186]
# [metis/urdf_spawnermetis-110] process has finished cleanly
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/metis-urdf_spawnermetis-110*.log
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch started with run-time arguments ['Y:=-17.95423287', 'X:=-37.2823487136', 'laser_sensor:=False', 'yaw:=5.1611879309', 'robot:=metis']
# started roslaunch server http://ivory.local:42297/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /enable_statistics: True
#  * /himalia/distanceEstimator/angle_max: 10.0
#  * /himalia/distanceEstimator/angle_min: -10.0
#  * /himalia/distanceEstimator/scan_topic: /himalia/front_la...
#  * /himalia/front_left_steering_position_controller/joint: front_left_steeri...
#  * /himalia/front_left_steering_position_controller/pid/d: 10.0
#  * /himalia/front_left_steering_position_controller/pid/i: 0.01
#  * /himalia/front_left_steering_position_controller/pid/p: 100.0
#  * /himalia/front_left_steering_position_controller/type: position_controll...
#  * /himalia/front_right_steering_position_controller/joint: front_right_steer...
# ...
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537004.031356]: Control for vehicle zel terminated
# [zel/global_frame_tf_zel-46] killing on exit
# [zel/robot_state_publisherzel-40] killing on exit
# [zel/odom2pathzel-45] killing on exit
# [zel/base_link2slamodom_tf_zel-42] killing on exit
# [zel/controller_spawnerzel-39] killing on exit
# [zel/distanceEstimator-44] killing on exit
# [zel/cmdvel2gazebozel-43] killing on exit
# [zel/joint_state_publisherzel-41] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [zephyr/velinjector_zephyr-196] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537005.572178]: Control for vehicle zephyr terminated
# [zephyr/odom2pathzephyr-54] killing on exit
# [zephyr/global_frame_tf_zephyr-55] killing on exit
# [zephyr/base_link2slamodom_tf_zephyr-51] killing on exit
# [zephyr/cmdvel2gazebozephyr-52] killing on exit
# [zephyr/joint_state_publisherzephyr-50] killing on exit
# [zephyr/distanceEstimator-53] killing on exit
# [zephyr/robot_state_publisherzephyr-49] killing on exit
# [zephyr/controller_spawnerzephyr-48] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [centauri/velinjector_centauri-197] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537007.507479]: Control for vehicle centauri terminated
# [centauri/global_frame_tf_centauri-64] killing on exit
# [centauri/odom2pathcentauri-63] killing on exit
# [centauri/distanceEstimator-62] killing on exit
# [centauri/cmdvel2gazebocentauri-61] killing on exit
# [centauri/robot_state_publishercentauri-58] killing on exit
# [centauri/joint_state_publishercentauri-59] killing on exit
# [centauri/base_link2slamodom_tf_centauri-60] killing on exit
# [centauri/controller_spawnercentauri-57] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [zenith/velinjector_zenith-198] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537009.236816]: Control for vehicle zenith terminated
# [zenith/global_frame_tf_zenith-73] killing on exit
# [zenith/cmdvel2gazebozenith-70] killing on exit
# [zenith/distanceEstimator-71] killing on exit
# [zenith/robot_state_publisherzenith-67] killing on exit
# [zenith/controller_spawnerzenith-66] killing on exit
# [zenith/base_link2slamodom_tf_zenith-69] killing on exit
# [zenith/odom2pathzenith-72] killing on exit
# [zenith/joint_state_publisherzenith-68] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [europa/velinjector_europa-199] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537011.320219]: Control for vehicle europa terminated
# [europa/odom2patheuropa-81] killing on exit
# [europa/distanceEstimator-80] killing on exit
# [europa/global_frame_tf_europa-82] killing on exit
# [europa/cmdvel2gazeboeuropa-79] killing on exit
# [europa/joint_state_publishereuropa-77] killing on exit
# [europa/robot_state_publishereuropa-76] killing on exit
# [europa/base_link2slamodom_tf_europa-78] killing on exit
# [europa/controller_spawnereuropa-75] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [elara/velinjector_elara-200] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537013.245757]: Control for vehicle elara terminated
# [elara/base_link2slamodom_tf_elara-87] killing on exit
# [elara/cmdvel2gazeboelara-88] killing on exit
# [elara/odom2pathelara-90] killing on exit
# [elara/robot_state_publisherelara-85] killing on exit
# [elara/joint_state_publisherelara-86] killing on exit[elara/global_frame_tf_elara-91] killing on exit
#
# [elara/controller_spawnerelara-84] killing on exit
# [elara/distanceEstimator-89] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [herse/velinjector_herse-201] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537014.634692]: Control for vehicle herse terminated
# [herse/global_frame_tf_herse-100] killing on exit
# [herse/base_link2slamodom_tf_herse-96] killing on exit
# [herse/cmdvel2gazeboherse-97] killing on exit
# [herse/odom2pathherse-99] killing on exit
# [herse/distanceEstimator-98] killing on exit
# [herse/controller_spawnerherse-93] killing on exit
# [herse/robot_state_publisherherse-94] killing on exit[herse/joint_state_publisherherse-95] killing on exit
#
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [thebe/velinjector_thebe-202] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537016.041029]: Control for vehicle thebe terminated
# [thebe/global_frame_tf_thebe-109] killing on exit
# [thebe/odom2paththebe-108] killing on exit
# [thebe/cmdvel2gazebothebe-106] killing on exit
# [thebe/distanceEstimator-107] killing on exit
# [thebe/base_link2slamodom_tf_thebe-105] killing on exit
# [thebe/robot_state_publisherthebe-103] killing on exit
# [thebe/joint_state_publisherthebe-104] killing on exit
# [thebe/controller_spawnerthebe-102] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [metis/velinjector_metis-203] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537017.345352]: Control for vehicle metis terminated
# [metis/global_frame_tf_metis-118] killing on exit
# [metis/distanceEstimator-116] killing on exit
# [metis/cmdvel2gazebometis-115] killing on exit
# [metis/odom2pathmetis-117] killing on exit
# [metis/controller_spawnermetis-111] killing on exit
# [metis/joint_state_publishermetis-113] killing on exit
# [metis/base_link2slamodom_tf_metis-114] killing on exit
# [metis/robot_state_publishermetis-112] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [himalia/velinjector_himalia-204] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537018.711217]: Control for vehicle himalia terminated
# [himalia/global_frame_tf_himalia-127] killing on exit
# [himalia/base_link2slamodom_tf_himalia-123] killing on exit
# [himalia/distanceEstimator-125] killing on exit
# [himalia/odom2pathhimalia-126] killing on exit
# [himalia/cmdvel2gazebohimalia-124] killing on exit
# [himalia/robot_state_publisherhimalia-121] killing on exit
# [himalia/joint_state_publisherhimalia-122] killing on exit
# [himalia/controller_spawnerhimalia-120] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [kalyke/velinjector_kalyke-205] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537020.005393]: Control for vehicle kalyke terminated
# [kalyke/global_frame_tf_kalyke-136] killing on exit
# [kalyke/odom2pathkalyke-135] killing on exit
# [kalyke/distanceEstimator-134] killing on exit
# [kalyke/base_link2slamodom_tf_kalyke-132] killing on exit
# [kalyke/robot_state_publisherkalyke-130] killing on exit
# [kalyke/cmdvel2gazebokalyke-133] killing on exit
# [kalyke/joint_state_publisherkalyke-131] killing on exit
# [kalyke/controller_spawnerkalyke-129] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [carpo/velinjector_carpo-206] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537021.147585]: Control for vehicle carpo terminated
# [carpo/global_frame_tf_carpo-145] killing on exit
# [carpo/odom2pathcarpo-144] killing on exit
# [carpo/cmdvel2gazebocarpo-142] killing on exit
# [carpo/distanceEstimator-143] killing on exit
# [carpo/base_link2slamodom_tf_carpo-141] killing on exit
# [carpo/joint_state_publishercarpo-140] killing on exit
# [carpo/robot_state_publishercarpo-139] killing on exit
# [carpo/controller_spawnercarpo-138] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [arche/velinjector_arche-207] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537022.757243]: Control for vehicle arche terminated
# [arche/global_frame_tf_arche-154] killing on exit[arche/odom2patharche-153] killing on exit
#
# [arche/distanceEstimator-152] killing on exit
# [arche/cmdvel2gazeboarche-151] killing on exit
# [arche/base_link2slamodom_tf_arche-150] killing on exit
# [arche/joint_state_publisherarche-149] killing on exit
# [arche/robot_state_publisherarche-148] killing on exit
# [arche/controller_spawnerarche-147] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [aitne/velinjector_aitne-208] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537024.132153]: Control for vehicle aitne terminated
# [aitne/global_frame_tf_aitne-163] killing on exit
# [aitne/odom2pathaitne-162] killing on exit
# [aitne/distanceEstimator-161] killing on exit
# [aitne/cmdvel2gazeboaitne-160] killing on exit
# [aitne/base_link2slamodom_tf_aitne-159] killing on exit
# [aitne/joint_state_publisheraitne-158] killing on exit
# [aitne/robot_state_publisheraitne-157] killing on exit
# [aitne/controller_spawneraitne-156] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [thyone/velinjector_thyone-209] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537025.260820]: Control for vehicle thyone terminated
# [thyone/distanceEstimator-170] killing on exit
# [thyone/global_frame_tf_thyone-172] killing on exit
# [thyone/base_link2slamodom_tf_thyone-168] killing on exit
# [thyone/controller_spawnerthyone-165] killing on exit
# [thyone/joint_state_publisherthyone-167] killing on exit
# [thyone/cmdvel2gazebothyone-169] killing on exit
# [thyone/odom2paththyone-171] killing on exit
# [thyone/robot_state_publisherthyone-166] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [enceladus/velinjector_enceladus-210] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537026.471403]: Control for vehicle enceladus terminated
# [enceladus/odom2pathenceladus-180] killing on exit
# [enceladus/global_frame_tf_enceladus-181] killing on exit
# [enceladus/base_link2slamodom_tf_enceladus-177] killing on exit
# [enceladus/controller_spawnerenceladus-174] killing on exit
# [enceladus/distanceEstimator-179] killing on exit
# [enceladus/cmdvel2gazeboenceladus-178] killing on exit
# [enceladus/robot_state_publisherenceladus-175] killing on exit
# [enceladus/joint_state_publisherenceladus-176] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# [mimas/velinjector_mimas-211] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/sparkle/launch/velinjector.launch Terminated.
# [INFO] [1603537027.436801]: Control for vehicle mimas terminated
# [mimas/global_frame_tf_mimas-190] killing on exit
# [mimas/odom2pathmimas-189] killing on exit
# [mimas/distanceEstimator-188] killing on exit
# [mimas/joint_state_publishermimas-185] killing on exit
# [mimas/base_link2slamodom_tf_mimas-186] killing on exit
# [mimas/cmdvel2gazebomimas-187] killing on exit
# [mimas/robot_state_publishermimas-184] killing on exit
# [mimas/controller_spawnermimas-183] killing on exit
# /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/launch/catvehicle_spawn.launch Terminated.
# Destroying ros-rviz
# Destroying physics world
# all processes on machine have died, roslaunch will exit
# Stopping ROSBAG Recorder.
# Retrieving the latest bag file
# [gazebo-1] process has died [pid 19222, exit code -15, cmd /opt/ros/melodic/lib/gazebo_ros/gzserver -e ode /home/ivory/VersionControl/catvehicle_ws/src/catvehicle/worlds/plane.world __name:=gazebo __log:=/home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/gazebo-1.log].
# log file: /home/ivory/.ros/log/6654feee-15e6-11eb-9142-144f8af0bf40/gazebo-1*.log
# Bag file is still being written. Bytes written: 83946
# Bag file is still being written. Bytes written: 78756
# Bag file is still being written. Bytes written: 96009
# Bag file is still being written. Bytes written: 91735
# Bag file is still being written. Bytes written: 91429
# Bag file is still being written. Bytes written: 148030
# Bag file is still being written. Bytes written: 90209
# Bag file is still being written. Bytes written: 91111
# Bag file is still being written. Bytes written: 87465
# Bag file is still being written. Bytes written: 86082
# Bag file is still being written. Bytes written: 74306
# Bag file is still being written. Bytes written: 87172
# Bag file is still being written. Bytes written: 86388
# Bag file is still being written. Bytes written: 85768
# Bag file is still being written. Bytes written: 144199
# Bag file is still being written. Bytes written: 82561
# Bag file is still being written. Bytes written: 81512
# Bag file is still being written. Bytes written: 81196
# Bag file is still being written. Bytes written: 79825
# Bag file is still being written. Bytes written: 78291
# Bag file is still being written. Bytes written: 77824
# Bag file is still being written. Bytes written: 78021
# Bag file is still being written. Bytes written: 77844
# Bag file is still being written. Bytes written: 74486
# Bag file is still being written. Bytes written: 133364
# Bag file is still being written. Bytes written: 73254
# Bag file is still being written. Bytes written: 73268
# Bag file is still being written. Bytes written: 72791
# Bag file is still being written. Bytes written: 69755
# Bag file is still being written. Bytes written: 559633
# Bag file is still being written. Bytes written: 444725
# Bag file is still being written. Bytes written: 10650428
# .active bag file is gone.
# Bag file catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03.bag successfully written
# bag file saved successfully
# rosnode kill: (None, None)
# ps -aef  STDOUT:(None, None)
# Retrieving latest bag file
# Bag File Recorded Is: catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03.bag
# mkdir STDOUT:("mkdir: created directory 'catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03'\n", None)
# Renaming GZStat log file [/home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/gz_stats_2020-10-24-03-51-06-589926.txt] to retain bag file information
# mv STDOUT:("renamed '/home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/gz_stats_2020-10-24-03-51-06-589926.txt' -> 'catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03/catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03_gzStats.txt'\n", None)
# Killing roscore
# psutil.Process(pid=19038, name='sh', started='03:48:05')
# [psutil.Process(pid=19039, name='roscore', started='03:48:05'), psutil.Process(pid=19051, name='rosmaster', started='03:48:06'), psutil.Process(pid=19063, name='rosout', started='03:48:07')]
# Attempted to kill child: psutil.Process(pid=19039, name='roscore', started='03:48:05')
# Attempted to kill child: psutil.Process(pid=19051, name='rosmaster', started='03:48:06')
# Attempted to kill child: psutil.Process(pid=19063, name='rosout', started='03:48:07')
# ##### Simulation Terminated #####

# %% [markdown]
# ## Analysis

# %%
bag = C.latesbag()
gz_stat_file = C.gzstatsfile
GZ = gzstats(gz_stat_file)
GZ.dataframe.to_csv(gz_stat_file[0:-4]+".csv")

fig, ax = bagpy.create_fig(1)
fig.set_figwidth(10)
sea.lineplot(x = 'SimTime', y = 'Factor', data = GZ.dataframe, ax = ax[0])
ax[0].set_title("Real Time Factor vs Sim Time")
fig.show()
# Out:
# Retrieving latest bag file
# Bag File Recorded Is: catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03.bag
# mkdir STDOUT:('', None)
# Renaming GZStat log file [catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03/catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03_gzStats.txt] to retain bag file information
# mv STDOUT:('', None)
# /home/ivory/.local/lib/python2.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
b = bagreader(bag)
b.topic_table
# Out:
# [INFO]  Data folder /home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03 already exists. Not creating.
#                       Topics                          Types  Message Count  \
# 0                 /magna/vel            geometry_msgs/Twist            939
# 1              /zel/steering           geometry_msgs/Wrench            865
# 2          /calista/steering           geometry_msgs/Wrench            958
# 3               /europa/path                  nav_msgs/Path             99
# 4           /nebula/steering           geometry_msgs/Wrench            950
# 5        /aitne/joint_states         sensor_msgs/JointState           1068
# 6                  /zel/path                  nav_msgs/Path             68
# 7      /himalia/joint_states         sensor_msgs/JointState           1047
# 8                /statistics  rosgraph_msgs/TopicStatistics           2855
# 9              /himalia/odom              nav_msgs/Odometry            985
# 10               /zephyr/vel            geometry_msgs/Twist            866
# 11               /elara/path                  nav_msgs/Path             63
# 12              /zenith/odom              nav_msgs/Odometry            856
# 13              /kalyke/odom              nav_msgs/Odometry            976
# 14          /kalyke/steering           geometry_msgs/Wrench            890
# 15      /zenith/joint_states         sensor_msgs/JointState           1062
# 16                       /tf             tf2_msgs/TFMessage         107101
# 17             /centauri/vel            geometry_msgs/Twist            856
# 18             /himalia/path                  nav_msgs/Path             78
# 19           /enceladus/path                  nav_msgs/Path             94
# 20    /centauri/joint_states         sensor_msgs/JointState           1059
# 21               /herse/odom              nav_msgs/Odometry            977
# 22             /proxima/odom              nav_msgs/Odometry            995
# 23                /arche/vel            geometry_msgs/Twist            887
# 24      /gazebo/model_states        gazebo_msgs/ModelStates           2238
# 25       /carpo/joint_states         sensor_msgs/JointState           1353
# 26             /calista/path                  nav_msgs/Path             79
# 27      /kalyke/joint_states         sensor_msgs/JointState            995
# 28               /metis/odom              nav_msgs/Odometry            978
# 29       /arche/joint_states         sensor_msgs/JointState           1274
# ..                       ...                            ...            ...
# 85                /mimas/vel            geometry_msgs/Twist            894
# 86               /magna/path                  nav_msgs/Path             62
# 87           /arche/steering           geometry_msgs/Wrench            798
# 88               /rosout_agg              rosgraph_msgs/Log             25
# 89               /thebe/odom              nav_msgs/Odometry            892
# 90               /nebula/vel            geometry_msgs/Twist            856
# 91                /aitne/vel            geometry_msgs/Twist            799
# 92                    /clock            rosgraph_msgs/Clock            870
# 93              /proxima/vel            geometry_msgs/Twist            863
# 94               /mimas/path                  nav_msgs/Path             81
# 95         /zel/joint_states         sensor_msgs/JointState           1267
# 96              /nebula/path                  nav_msgs/Path             61
# 97              /kalyke/path                  nav_msgs/Path             61
# 98                /metis/vel            geometry_msgs/Twist            791
# 99         /himalia/steering           geometry_msgs/Wrench            794
# 100             /thyone/path                  nav_msgs/Path             87
# 101         /zenith/steering           geometry_msgs/Wrench            764
# 102             /nebula/odom              nav_msgs/Odometry            877
# 103           /centauri/path                  nav_msgs/Path             79
# 104             /zephyr/odom              nav_msgs/Odometry            762
# 105  /enceladus/joint_states         sensor_msgs/JointState            947
# 106          /aitne/steering           geometry_msgs/Wrench            934
# 107      /gazebo/link_states         gazebo_msgs/LinkStates            860
# 108           /centauri/odom              nav_msgs/Odometry            763
# 109           /enceladus/vel            geometry_msgs/Twist            833
# 110              /carpo/odom              nav_msgs/Odometry            905
# 111              /thyone/vel            geometry_msgs/Twist            846
# 112       /centauri/steering           geometry_msgs/Wrench            757
# 113          /metis/steering           geometry_msgs/Wrench            778
# 114            /calista/odom              nav_msgs/Odometry            885
#
#     Frequency
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# ..        ...
# 85       None
# 86       None
# 87       None
# 88       None
# 89       None
# 90       None
# 91       None
# 92       None
# 93       None
# 94       None
# 95       None
# 96       None
# 97       None
# 98       None
# 99       None
# 100      None
# 101      None
# 102      None
# 103      None
# 104      None
# 105      None
# 106      None
# 107      None
# 108      None
# 109      None
# 110      None
# 111      None
# 112      None
# 113      None
# 114      None
#
# [115 rows x 4 columns]

# %%
df_odom = []
b = bagreader(bag)
for nm in C.name:
    print("Car: {}".format(nm))
    setvelfile = b.message_by_topic('/' + nm + '/odom')
    if setvelfile is None:
        continue
    setvel = pd.read_csv(setvelfile)
    df_odom.append(setvel)
# Out:
# [INFO]  Data folder /home/ivory/CyverseData/ProjectSparkle/RTFvsNVehicles/catvehicle_n_21_update_rate_20.0_max_update_rate_100.0_time_step_0.01_logtime_120.0_2020-10-24-03-51-03 already exists. Not creating.
# Car: magna
# Car: nebula
# Car: calista
# Car: proxima
# Car: zel
# Car: zephyr
# Car: centauri
# Car: zenith
# Car: europa
# Car: elara
# Car: herse
# Car: thebe
# Car: metis
# Car: himalia
# Car: kalyke
# Car: carpo
# Car: arche
# Car: aitne
# Car: thyone
# Car: enceladus
# Car: mimas
# Car: tethys
# No data on the topic:/tethys/odom
# Car: lapetus
# No data on the topic:/lapetus/odom
# Car: dione
# No data on the topic:/dione/odom
# Car: phoebe
# No data on the topic:/phoebe/odom
# Car: epimetheus
# No data on the topic:/epimetheus/odom
# Car: hyperion
# No data on the topic:/hyperion/odom
# Car: rhea
# No data on the topic:/rhea/odom
# Car: telesto
# No data on the topic:/telesto/odom
# Car: deimos
# No data on the topic:/deimos/odom
# Car: phobos
# No data on the topic:/phobos/odom
# Car: triton
# No data on the topic:/triton/odom
# Car: proteus
# No data on the topic:/proteus/odom
# Car: nereid
# No data on the topic:/nereid/odom
# Car: larissa
# No data on the topic:/larissa/odom
# Car: galatea
# No data on the topic:/galatea/odom
# Car: despina
# No data on the topic:/despina/odom
# Car: sirius
# No data on the topic:/sirius/odom
# Car: rigel
# No data on the topic:/rigel/odom
# Car: vega
# No data on the topic:/vega/odom
# Car: altair
# No data on the topic:/altair/odom
# Car: capella
# No data on the topic:/capella/odom
# Car: alcor
# No data on the topic:/alcor/odom
# Car: whirlpool
# No data on the topic:/whirlpool/odom
# Car: andromeda
# No data on the topic:/andromeda/odom
# Car: milkyway
# No data on the topic:/milkyway/odom
# Car: cygnus
# No data on the topic:/cygnus/odom

# %%
fig, ax = bagpy.create_fig(1)
for df in df_odom:
    ax[0].scatter(x = 'Time', y = 'pose.pose.position.y', data = df, s= 1)
    
fig.show()

# %%
C_init_straight = []
for i in range(0, 21):
    theta = math.atan2(C.Y[i], C.X[i])
    
    straight_len = C.R*(theta)
    
    if theta < 0.0:
        theta2 = theta + np.pi
        straight_len = C.R*(theta2)
        straight_len = straight_len + np.pi*C.R
    print(straight_len)
    
        
    C_init_straight.append(straight_len)
# Out:
# 0.0
# 12.380952381
# 24.7619047619
# 37.1428571429
# 49.5238095238
# 61.9047619048
# 74.2857142857
# 86.6666666667
# 99.0476190476
# 111.428571429
# 123.80952381
# 136.19047619
# 148.571428571
# 160.952380952
# 173.333333333
# 185.714285714
# 198.095238095
# 210.476190476
# 222.857142857
# 235.238095238
# 247.619047619

# %%
for i, df in enumerate(df_odom):
    df['distance_per_step'] = 0
    distance_per_step = [C_init_straight[i]]
    df['distance'] = 0
    sum = C_init_straight[i]
    cum_sum = [C_init_straight[i]]
    for index, row in df.iloc[1:].iterrows():

        x = df['pose.pose.position.x'][index]
        y = df['pose.pose.position.y'][index]

        x_old = df['pose.pose.position.x'][index-1]
        y_old = df['pose.pose.position.y'][index-1]
        if np.abs(y) < 0.0001:
            y = 0
        if np.abs(x) < 0.0001:
            x = 0

        if np.abs(y_old) < 0.0001:
            y_old = 0
        if np.abs(x_old) < 0.0001:
            x_old = 0


        theta = math.atan2(y, x)
        theta_old = math.atan2(y_old, x_old)
        d_per_step = C.R*(np.abs(theta - theta_old))
        distance_per_step.append(d_per_step)
        sum = sum + d_per_step
        sum = sum%260
        cum_sum.append(sum)

    df['distance_per_step'] =distance_per_step
    df['distance'] = cum_sum

# %%
fig, ax = bagpy.create_fig(1)
fig.set_figwidth(18)
fig.set_figheight(8)
for i, df in enumerate(df_odom):
    df = df.iloc[:-300]
    ax[0].plot(df['Time'], df['distance'], linewidth = 0, marker = '.', label = C.name[i],markersize = 2, 
              color = '#22223b')
    #ax[0].scatter(x = 'Time', y = 'distance', data = df, s= 1, label = C.name[i])
    
    
#ax[0].legend(fontsize = 20, ncol = 6, markerscale = 4)
ax[0].set_ylim(0, 300)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Position on the Circle')
ax[0].set_title('Time-Space Diagram')
fig.show()

# %%
statistics_file = b.message_by_topic('/statistics')
statistics = pd.read_csv(statistics_file)
fig, ax = bagpy.create_fig(2)
ax[0].scatter(x = 'Time', y = 'dropped_msgs', data =statistics, label = 'No. of Messages Dropped', alpha = 0.5, s = 20, c = '#0f4c5c')
ax[1].scatter(x = 'Time', y = 'delivered_msgs', data =statistics, label = 'No. of Messages Delivered',alpha = 0.5,  s = 20, c = '#772e25')
ax[0].legend(markerscale = 4, fontsize = 20)
ax[1].legend(markerscale = 4, fontsize = 20)
ax[0].set_xlabel('Time')
ax[1].set_xlabel('Time')

fig.show()
